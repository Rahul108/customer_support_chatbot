# %% [markdown]
# # Customer Support Chatbot - Project Exploration
#
# This notebook demonstrates:
# 1. Setting up the project environment
# 2. Loading configurations
# 3. Basic model initialization
# 4. Project structure overview

# %%
import sys
import os
project_root = os.path.abspath('..')
sys.path.insert(0, project_root)
print(f'Project root: {project_root}')
print(f'Python version: {sys.version}')

# %% [markdown]
# ## 1. Import Configuration

# %%
from config.settings import Config

config = Config()
print('Configuration Loaded!')
print(f'Base Model: {config.model.base_model}')
print(f'Max Length: {config.model.max_length}')
print(f'Device: {config.model.model_device}')

# %% [markdown]
# ## 2. View Component Settings

# %%
print('=== LoRA Configuration ===')
print(f'Rank (r): {config.lora.r}')
print(f'Alpha: {config.lora.lora_alpha}')
print(f'Dropout: {config.lora.lora_dropout}')

print('\n=== Training Configuration ===')
print(f'Learning Rate: {config.training.learning_rate}')
print(f'Batch Size: {config.training.batch_size}')
print(f'Num Epochs: {config.training.num_epochs}')
