# %% [markdown]
# # Adaptation Techniques: LoRA, Adapters, and PEFT
#
# Three parameter-efficient fine-tuning techniques

# %%
from config.settings import Config
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')

# %% [markdown]
# ## 1. LoRA (Low-Rank Adaptation)

# %%
print('=== LoRA: Low-Rank Adaptation ===')
print('Updates weights by learning low-rank decomposition matrices')

config = Config()
print(f'\nLoRA Configuration:')
print(f'  Rank (r): {config.lora.r}')
print(f'  Alpha: {config.lora.lora_alpha}')
print(f'  Dropout: {config.lora.lora_dropout}')

# %% [markdown]
# ## 2. Adapters

# %%
print('=== Adapters: Bottleneck Architecture ===')
print('Insert small bottleneck layers between transformer blocks')

print(f'\nAdapter Configuration:')
print(f'  Adapter Size: {config.adapter.adapter_size}')
print(f'  Activation: {config.adapter.activation}')
print(f'  Dropout: {config.adapter.dropout}')

# %% [markdown]
# ## 3. PEFT (Unified Interface)

# %%
print('=== PEFT: Parameter-Efficient Fine-Tuning ===')
print('Unified interface for multiple adaptation techniques')
print('\nSupported Techniques:')
print('  1. LoRA - Low-rank decomposition')
print('  2. Adapters - Bottleneck layers')
print('  3. PEFT - Unified wrapper')
